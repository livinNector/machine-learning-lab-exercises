# %% [markdown]
# # Exercise 9 - Isolated Word Speech Recognition

# %% [markdown]
# ## a)Isolated Word speech recognition using CNN
#
# ### Program 1 - Implementing Isolated word speech recognition in speech commands dataset Using CNN

# %% [markdown]
# #### AIM
# To build isolated word speech recognition model using CNN on the spech commands dataset and test it with recorded audio which is not from the dataset
#
# #### About the Dataset
# (2018) Speech commands dataset version 2. Available: http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz
#
# **Note:** Only the words bed, cat and happy are used in this exercise
#
# #### Modules used:
#
# | Modules         | Version   |
# | --------------  | --------- |
# | tensorflow      |  2.6.0    |
# | numpy           |  1.19.5   |
# | librosa         |  0.8.1    |
# | matplotlib      |  3.4.3    |
# | ipython         |  7.26.0   |
#
# #### Neural Network Architecture
#
# | Layer (type) | Output Shape       |
# | ------------ | ------------------ |
# | Conv2D       | (None, 11, 29, 32) |
# | Conv2D       | (None, 9, 27, 48)  |
# | Conv2D       | (None, 6, 24, 64)  |
# | MaxPooling2D | (None, 1, 6, 64)   |
# | Dropout      | (None, 1, 6, 64)   |
# | Flatten      | (None, 384)        |
# | Dense        | (None, 128)        |
# | Dropout      | (None, 128)        |
# | Dense        | (None, 64)         |
# | Dropout      | (None, 64)         |
# | Dense        | (None, 3)          |

# %% [markdown]
# #### Part 1 - Loading the the audio files and extracting mfcc feature from the audio files

# %%
import numpy as np
import librosa

# %%
data_path = "./datasets/isolated_word_dataset"
labels = np.array(["bed","cat","happy"])
n_classes = labels.shape[0]
n_mfcc = 12 # no. of mfc coefficients
t = 30 # no. of time windows on which the mfc coefficients are computed
input_shape = (-1,n_mfcc,t,1)

# %%
def wav2mfcc(file,t,n_mfcc):
    data, sr = librosa.load(file,sr=None)
    mfcc = librosa.feature.mfcc(data,sr,n_mfcc =n_mfcc)
    if mfcc.shape[1]>t:
        mfcc = mfcc[:,:t]
    if mfcc.shape[1]<t:
        mfcc = np.pad(mfcc,pad_width=((0,0),(0,t- mfcc.shape[1])))
    return mfcc

# %%
def load_speech_dataset_features(data_path,labels):
    X,y = [],[]
    for i,label in enumerate(labels):
        file_name = f"{data_path}/{label}.npy"
        try:
            data = np.load(file_name)
        except(FileNotFoundError):
            data = np.array([
                wav2mfcc(file,t = t,n_mfcc=n_mfcc) 
                for file in librosa.util.find_files(f"{data_path}/{label}/")
            ])
            np.save(file_name,data)
        X.append(data)
        y.append(np.full((data.shape[0],1),i))
    X = np.vstack(X).reshape(input_shape)
    y = np.vstack(y)==np.arange(n_classes) # y is one hot encoded     
    return X,y

# %%
X,y = load_speech_dataset_features(data_path,labels)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2)
X_train,X_test = X_train,X_test

# %% [markdown]
# #### Part  - CNN Architecture Design

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adadelta

# %%
def get_model():
    model = Sequential()
    
    model.add(Conv2D(
        32, kernel_size=(2, 2), activation='relu',
        input_shape=(n_mfcc,t , 1)
    ))
    model.add(Conv2D(48, kernel_size=(3, 3), activation='relu'))
    model.add(Conv2D(64, kernel_size=(4, 4), activation='relu'))
    model.add(MaxPooling2D(pool_size=(4, 4)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(
        loss=CategoricalCrossentropy(),
        optimizer=Adadelta(.3),
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# #### Part 3 - Training the model

# %%
tf.random.set_seed(0)
model = get_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 11, 29, 32)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 27, 48)         13872
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 24, 64)         49216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 6, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 384)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               49280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 120,979
# Trainable params: 120,979
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(
    X_train, y_train, batch_size=50, epochs=50,
    verbose=True, validation_data=(X_test, y_test)
)
tf.keras.models.save_model(model,"./models/isolated_word_speech_recognition_model.h5")
model = tf.keras.models.load_model("./models/isolated_word_speech_recognition_model.h5")
# Out:
# Epoch 1/50
# 83/83 [==============================] - 10s 112ms/step - loss: 1.6681 - accuracy: 0.4725 - val_loss: 0.6629 - val_accuracy: 0.7669
# Epoch 2/50
# 83/83 [==============================] - 9s 108ms/step - loss: 0.7353 - accuracy: 0.6896 - val_loss: 0.4412 - val_accuracy: 0.8487
# Epoch 3/50
# 83/83 [==============================] - 9s 109ms/step - loss: 0.5424 - accuracy: 0.7945 - val_loss: 0.3388 - val_accuracy: 0.8844
# Epoch 4/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.4257 - accuracy: 0.8388 - val_loss: 0.2706 - val_accuracy: 0.9085
# Epoch 5/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.3286 - accuracy: 0.8798 - val_loss: 0.2285 - val_accuracy: 0.9210
# Epoch 6/50
# 83/83 [==============================] - 9s 109ms/step - loss: 0.2682 - accuracy: 0.9005 - val_loss: 0.1803 - val_accuracy: 0.9374
# Epoch 7/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.2198 - accuracy: 0.9169 - val_loss: 0.1693 - val_accuracy: 0.9422
# Epoch 8/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1976 - accuracy: 0.9361 - val_loss: 0.1710 - val_accuracy: 0.9422
# Epoch 9/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1679 - accuracy: 0.9393 - val_loss: 0.2079 - val_accuracy: 0.9287
# Epoch 10/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1489 - accuracy: 0.9455 - val_loss: 0.1389 - val_accuracy: 0.9509
# Epoch 11/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1396 - accuracy: 0.9533 - val_loss: 0.1022 - val_accuracy: 0.9663
# Epoch 12/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1294 - accuracy: 0.9525 - val_loss: 0.2074 - val_accuracy: 0.9383
# Epoch 13/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1140 - accuracy: 0.9593 - val_loss: 0.1007 - val_accuracy: 0.9615
# Epoch 14/50
# 83/83 [==============================] - 9s 109ms/step - loss: 0.1022 - accuracy: 0.9670 - val_loss: 0.0960 - val_accuracy: 0.9634
# Epoch 15/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0835 - accuracy: 0.9694 - val_loss: 0.1362 - val_accuracy: 0.9615
# Epoch 16/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0855 - accuracy: 0.9713 - val_loss: 0.1025 - val_accuracy: 0.9605
# Epoch 17/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0879 - accuracy: 0.9696 - val_loss: 0.0728 - val_accuracy: 0.9701
# Epoch 18/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0637 - accuracy: 0.9790 - val_loss: 0.0704 - val_accuracy: 0.9778
# Epoch 19/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0717 - accuracy: 0.9764 - val_loss: 0.1033 - val_accuracy: 0.9672
# Epoch 20/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0688 - accuracy: 0.9781 - val_loss: 0.0655 - val_accuracy: 0.9711
# Epoch 21/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0574 - accuracy: 0.9817 - val_loss: 0.0803 - val_accuracy: 0.9740
# Epoch 22/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0491 - accuracy: 0.9829 - val_loss: 0.0785 - val_accuracy: 0.9759
# Epoch 23/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0574 - accuracy: 0.9805 - val_loss: 0.0763 - val_accuracy: 0.9750
# Epoch 24/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0547 - accuracy: 0.9827 - val_loss: 0.0841 - val_accuracy: 0.9740
# Epoch 25/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0481 - accuracy: 0.9834 - val_loss: 0.0798 - val_accuracy: 0.9721
# Epoch 26/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0414 - accuracy: 0.9846 - val_loss: 0.0881 - val_accuracy: 0.9711
# Epoch 27/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0329 - accuracy: 0.9889 - val_loss: 0.0890 - val_accuracy: 0.9721
# Epoch 28/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0585 - accuracy: 0.9805 - val_loss: 0.0857 - val_accuracy: 0.9711
# Epoch 29/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0453 - accuracy: 0.9841 - val_loss: 0.0790 - val_accuracy: 0.9769
# Epoch 30/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0307 - accuracy: 0.9877 - val_loss: 0.0788 - val_accuracy: 0.9778
# Epoch 31/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0339 - accuracy: 0.9880 - val_loss: 0.0820 - val_accuracy: 0.9769
# Epoch 32/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0315 - accuracy: 0.9894 - val_loss: 0.0920 - val_accuracy: 0.9788
# Epoch 33/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0356 - accuracy: 0.9894 - val_loss: 0.0998 - val_accuracy: 0.9759
# Epoch 34/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0374 - accuracy: 0.9877 - val_loss: 0.0895 - val_accuracy: 0.9730
# Epoch 35/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0276 - accuracy: 0.9911 - val_loss: 0.0877 - val_accuracy: 0.9759
# Epoch 36/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0257 - accuracy: 0.9908 - val_loss: 0.0719 - val_accuracy: 0.9769
# Epoch 37/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0214 - accuracy: 0.9942 - val_loss: 0.0716 - val_accuracy: 0.9750
# Epoch 38/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.0927 - val_accuracy: 0.9750
# Epoch 39/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0353 - accuracy: 0.9911 - val_loss: 0.0632 - val_accuracy: 0.9769
# Epoch 40/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0262 - accuracy: 0.9908 - val_loss: 0.0700 - val_accuracy: 0.9798
# Epoch 41/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0235 - accuracy: 0.9923 - val_loss: 0.1174 - val_accuracy: 0.9663
# Epoch 42/50
# 83/83 [==============================] - 9s 109ms/step - loss: 0.0172 - accuracy: 0.9954 - val_loss: 0.0920 - val_accuracy: 0.9798
# Epoch 43/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.0695 - val_accuracy: 0.9769
# Epoch 44/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0271 - accuracy: 0.9908 - val_loss: 0.0847 - val_accuracy: 0.9807
# Epoch 45/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0220 - accuracy: 0.9923 - val_loss: 0.0655 - val_accuracy: 0.9807
# Epoch 46/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.1311 - val_accuracy: 0.9721
# Epoch 47/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0207 - accuracy: 0.9935 - val_loss: 0.0786 - val_accuracy: 0.9759
# Epoch 48/50
# 83/83 [==============================] - 9s 111ms/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.0747 - val_accuracy: 0.9798
# Epoch 49/50
# 83/83 [==============================] - 9s 110ms/step - loss: 0.0224 - accuracy: 0.9947 - val_loss: 0.0575 - val_accuracy: 0.9798
# Epoch 50/50
# 83/83 [==============================] - 9s 113ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0822 - val_accuracy: 0.9778

# %% [markdown]
# #### Part 4 - Testing with real recorded audio speech

# %%
from IPython.display import Audio

# %%
for label in labels:
    file_name = f"{data_path}/recorded_test_audios/{label}.wav"
    test_audio,sr = librosa.load(file_name,sr=None,mono=True)
    print(f"File Nme: {label}.wav")
    display(Audio(test_audio, rate = sr))
    features = wav2mfcc(file_name,t,n_mfcc).reshape(input_shape)
    print("Predicted Output :", labels[np.argmax(model.predict(features))])
    print("-"*40)
# Out:
# File Nme: bed.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Predicted Output : bed
# ----------------------------------------
# File Nme: cat.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Predicted Output : cat
# ----------------------------------------
# File Nme: happy.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Predicted Output : happy
# ----------------------------------------
